# %%
import numpy as np

# %%
ar = np.array([[7,8,4],[2,1,9]])

# %%
 print(np.sort(ar))
# Out:
# [[4 7 8]
#  [1 2 9]]

# %%
ar = np.array([7,8,4,2,1,9])
s = np.where(ar % 2 == 0)
print(s)
# Out:
# (array([1, 2, 3]),)

# %%
arr = np.array([10,20,30,40,50,60,70,80,90])
ss = np.searchsorted(arr, 5)
print(ss+1)
# Out:
# 1

# %%
arr = np.array([10,20,30,40])
fa = [True, False, True, False]
x = arr[fa]
print(x)
# Out:
# [10 30]

# %%
arr = np.array([10,20,30,40])
fa = arr>35
x = arr[fa]
print(x)
# Out:
# [40]

# %%
arr = np.array([2,3,4,5])
fa = arr%2==1
x = arr[fa]
print(x)
# Out:
# [3 5]

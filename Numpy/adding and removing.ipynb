# %%
import numpy as np

a = np.array([[20,40],[40,80]])
print(np.append(a,[10,40]))
# Out:
# [20 40 40 80 10 40]

# %%
print(np.insert(a,0,10))
print(np.insert(a,1,[40,30], axis=1))
# Out:
# [10 20 40 40 80]
# [[20 40 40]
#  [40 30 80]]

# %%
a = np.array([[20,40],[60,80]])
print(a)
np.delete(a,1)
# Out:
# [[20 40]
#  [60 80]]
# array([20, 60, 80])

# %%
print(a)
# Out:
# [[20 40]
#  [60 80]]

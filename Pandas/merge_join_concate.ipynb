# %%
import pandas as pd

# %%
data1 = {"Emp Id": ["E01", "E02", "E03", "E04","E05", "E06"],
         "Names": ["Ram", "Shyam", "Rahul", "Vishal", "Ravi", "Raju"],
         "Age": [34,25,12,44,54,21]}

data2 = {"Emp Id": ["E01", "E02", "E03", "E04","E07", "E08"],
         "Salary": [45000,50000,40000,20000,10000,78000]}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
print(df1)
# Out:
#   Emp Id   Names  Age
# 0    E01     Ram   34
# 1    E02   Shyam   25
# 2    E03   Rahul   12
# 3    E04  Vishal   44
# 4    E05    Ravi   54
# 5    E06    Raju   21

# %%
print(df2)
# Out:
#   Emp Id  Salary
# 0    E01   45000
# 1    E02   50000
# 2    E03   40000
# 3    E04   20000
# 4    E07   10000
# 5    E08   78000

# %%
print(pd.merge(df1, df2, on="Emp Id", how="inner"))
# Out:
#   Emp Id   Names  Age  Salary
# 0    E01     Ram   34   45000
# 1    E02   Shyam   25   50000
# 2    E03   Rahul   12   40000
# 3    E04  Vishal   44   20000

# %%
import pandas as pd

data1 = {"Emp Id": ["E01", "E02", "E03", "E04","E05", "E06"],
         "Names": ["Ram", "Shyam", "Rahul", "Vishal", "Ravi", "Raju"],
         "Age": [34,25,12,44,54,21]}

data2 = {"Emp Id": ["E06", "E07", "E08", "E09","E010", "E011"],
         "Names": ["Hariom", "Krishna", "Ramu", "Harshit", "Chayan", "Raju"],
         "Age": [45,28,50,54,44,41]}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
print(pd.concat([df1, df2]))
# Out:
#   Emp Id    Names  Age
# 0    E01      Ram   34
# 1    E02    Shyam   25
# 2    E03    Rahul   12
# 3    E04   Vishal   44
# 4    E05     Ravi   54
# 5    E06     Raju   21
# 0    E06   Hariom   45
# 1    E07  Krishna   28
# 2    E08     Ramu   50
# 3    E09  Harshit   54
# 4   E010   Chayan   44
# 5   E011     Raju   41

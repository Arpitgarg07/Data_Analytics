# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [91,24,32,54,45]

plt.subplot(1,2,1)
plt.plot(x,y)
plt.show()


x = [5,6,7,8,9]
y = [67,50,66,56,82]
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

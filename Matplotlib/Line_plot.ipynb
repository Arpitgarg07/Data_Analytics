# %%
from cProfile import label

import matplotlib.pyplot as plt
import pandas as pd
from fontTools.diff import color
from openpyxl.chart import marker

# %%
x = ["day1", "day2", "day3", "day4", "day5"]
y = [300,400,250,230,400]
y1 = [500,450,300,250,320]

plt.plot(x,y,marker = 'o',ls = '-', color = 'green',label = "week1" )
plt.plot(x,y1,marker = 'o',ls = ':', color = 'red', label = "week2", alpha = 0.5 )
plt.legend()
plt.show()

# %%
data = pd.read_excel("expense3.xlsx")
df = pd.DataFrame(data)
grouped_by = df.groupby("Category")["Amount"].sum()
print(grouped_by)
plt.plot(grouped_by.index,grouped_by.values)
print(df)
plt.show()
# Out:
# Category
# 123             257
# Bills         18724
# Clothes        2890
# Essentials     4485
# Food           2765
# Grocery        1028
# Name: Amount, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 5
#       1 data = pd.read_excel("expense3.xlsx")
#       2 df = pd.DataFrame(data)
#       3 grouped_by = df.groupby("Category")["Amount"].sum()
#       4 print(grouped_by)
# ----> 5 plt.plot(grouped_by.index,grouped_by.values)
#       6 print(df)
#       7 plt.show()
#
# File H:\Data Analytics\.venv\Lib\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
# ...

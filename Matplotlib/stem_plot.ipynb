# %%
import matplotlib.pyplot as plt

# %%
x = [20,40,50,55,12,45,56,78,54]

plt.stem(x, linefmt="--", markerfmt="o", bottom=0, orientation="horizontal")
plt.show()

# %%
import pandas as pd

data = pd.read_excel("ESD.xlsx")
df = pd.DataFrame(data)
df2 = (df.head(50))
plt.stem(df["Age"])
plt.show()

# %%
plt.plot(df["Age"])
plt.show()
